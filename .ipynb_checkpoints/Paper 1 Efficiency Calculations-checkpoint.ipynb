# %%
using CSIM
# Out:
# Loading help data...

# %%
d20=0.0001294*2*pi
d24=0.00008125496*2*pi
# Out:
# 0.000510539970807465

# %%
using ImmutableArrays
c20=linSpiral(d20/(2*pi),0,.0254,250)
asb120=Assembly([translate(c20,Vector3(0.0,0.0,d20))])
asb220=Assembly([c20])
# Out:
# Assembly([linSpiral(0.0001294,0.0,0.0254,250.0,[0.0,0.0,0.0])])

# %%
Energies=[]
for i=.1:.05:.5
    E=coilEnergy(asb120,asb220,.1,50,.1,.008,[0,0,0],"LoadingBatch(.1to.5)3-27-14")
    vcat(Energies,E)
end

# %%
cap(t)=capacitorDischarge(500,t,0.0008)
# Out:
# cap (generic function with 1 method)

# %%
using ImmutableArrays
initCondi=[d20,0.]
# Out:
# 2-element Array{Float64,1}:
#  0.000813044
#  0.0

# %%
E=(.00532166-.000813)+.5*.1*1.58205^2
# Out:
# 0.129652770125

# %%
coilStateAfterDischarge(.1, asb120,asb220,t->-1*cap(t),cap,initCondi,0.0008*4)
# Out:
# Calculating Coil State
# 0
# .0
# 6
# .4e-6
# 9
# .6e-6
# 2
# .5599999999999992e-5
# 2
# .8444444444444447e-5
# 3
# .2e-5
# 3
# .199999999999999e-5
# 3
# .2e-5
# 6
# .927290446583413e-5
# 8
# .79093566987512e-5
# 0.
# 0001810916178633365
# 0.
# 00019765735318148507
# 0.
# 00021836452232917066
# 0.
# 0002183645223291706
# 0.
# 00021836452232917066
# 0.
# 0002584710902535092
# 0.
# 0002785243742156784
# 0.
# 00037879079402652465
# 0.
# 00039661593532623076
# 0.
# 00041889736195086316
# 0.
# 00041889736195086316
# 0.
# 00041889736195086316
# 0.
# 0004727475916742758
# 0.
# 0004996727065359821
# 0.
# 0006342982808445136
# 0.
# 0006582317162771416
# 0.
# 0006881485105679263
# 0.
# 0006881485105679262
# 0.
# 0006881485105679263
# 0.
# 0007736568701110541
# 0.
# 000816411049882618
# 0.
# 0010301819487404374
# 0.
# 0010681856640929388
# 0.
# 0011156903082835653
# 0.
# 0011156903082835653
# 0.
# 0011156903082835653
# 0.
# 0012238361746692292
# 0.
# 0012779091078620611
# 0.
# ...

# %%
out=_6
# Out:
# 0.129652770125

# %%
writecsv("out.csv",out)

# %%
using PyPlot
t=[0:.00001:.0008*10]
plot(t,cap(t))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x6a774d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0xcfe0ad0>

# %%
using PyPlot

# %%
translate!(asb120,Vector3(0.0,0.0,10.0))

# %%
plotter(asb220,.01)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x59fdbd0>)

# %%
plotter([asb120,asb220],.01)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0xd006050>)

# %%
coilEnergy(asb120,asb220,.1,50,.1,.008,[0,0,0],"test")
# Out:
# Calculating Coil State
# 0.0
# 6.4e-6
# 9.6e-6
# 2.5599999999999992e-5
# 2.8444444444444447e-5
# 3.2e-5
# 3.199999999999999e-5
# 3.2e-5
# 6.927290446583413e-5
# 8.79093566987512e-5
# 0.0001810916178633365
# 0.00019765735318148507
# 0.00021836452232917066
# 0.0002183645223291706
# 0.00021836452232917066
# 0.0002584710902535092
# 0.0002785243742156784
# 0.00037879079402652465
# 0.00039661593532623076
# 0.00041889736195086316
# 0.00041889736195086316
# 0.00041889736195086316
# 0.0004727475916742758
# 0.0004996727065359821
# 0.0006342982808445136
# 0.0006582317162771416
# 0.0006881485105679263
# 0.0006881485105679262
# 0.0006881485105679263
# 0.0007736568701110541
# 0.000816411049882618
# 0.0010301819487404374
# 0.0010681856640929388
# 0.0011156903082835653
# 0.0011156903082835653
# 0.0011156903082835653
# 0.0012238361746692292
# 0.0012779091078620611
# 0.0015482737738262207
# 0.0015963386033309606
# 0.001656419640211885
# 0.0016564196402118847
# 0.001656419640211885
# ...

# %%
A=[]
# Out:
# 0-element Array{None,1}

# %%
A=vcat(A,[1])
# Out:
# 1-element Array{Int64,1}:
#  1

# %%
A
# Out:
# 1-element Array{Int64,1}:
#  1
